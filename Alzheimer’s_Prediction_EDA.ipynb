# %% [markdown]
# <a href="https://colab.research.google.com/github/hapianalyst/Predicting-Alzheimer-s-Disease-Progression/blob/main/Alzheimer%E2%80%99s_Prediction_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Predicting Alzheimer’s Disease Progression: Machine Learning Classification of Alzheimer’s Disease and Mild Cognitive Impairment Using Diffusion Tensor Imaging (DTI) Biomarkers**
#
# MSc Dissertation - Alzheimer's Disease Prediction
#
#
# Research Questions:
#
# 1.   To what extent can ML algorithms accurately classify cognitive status using DTI-derived white matter features?
#
# 2.   Which specific DTI features are most strongly associated with Alzheimer's disease diagnosis?
#
# 3.   Does incorporating demographic variables improve model performance?

# %% [markdown]
# ## **Importing Important Libraries**

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    classification_report, confusion_matrix, accuracy_score,
    precision_score, recall_score, f1_score, roc_auc_score, roc_curve,
    precision_recall_curve, average_precision_score
)

# ML Algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing import label_binarize


# Feature Selection
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif, RFE
from sklearn.inspection import permutation_importance

# Statistical tests
from scipy import stats
from scipy.stats import chi2_contingency, ttest_ind, mannwhitneyu

# Utilities
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

# Set visualization style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

print("✓ All libraries imported successfully")
print(f"Analysis started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✓ All libraries imported successfully
# Analysis started: 2026-03-05 21:09:48

# %% [markdown]
# ## **Set-up Environment and Load the dataset**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Load the dataset
file_path = '/content/drive/MyDrive/ADSP_PHC_DTI_May2025.csv'

df = pd.read_csv(file_path)

print(f"✓ Dataset loaded successfully")
print(f"  Shape: {df.shape[0]:,} rows × {df.shape[1]:,} columns")
print(f"\nFirst few columns: {df.columns[:25].tolist()}")
# Out:
# ✓ Dataset loaded successfully
#   Shape: 3,026 rows × 13,771 columns
#
# First few columns: ['RID', 'PTID', 'PHASE', 'VISCODE2', 'VISCODE', 'PHC_LONIUID', 'SUBJID', 'PHC_Visit', 'PHC_Age_Cognition', 'PHC_Age_DTI', 'PHC_Diagnosis', 'PHC_Sex', 'PHC_Race', 'PHC_Ethnicity', 'PHC_Education', 'Imaging_Site', 'PHC_SCANDATE', 'Manufacturer', 'Model', 'FieldStrength', 'RepetitionTime', 'EchoTime', 'FlipAngle', 'PixelSpacing_X', 'PixelSpacing_Y']

# %%
# Display first few rows
df.head()
# Out:
#     RID        PTID  PHASE VISCODE2 VISCODE  PHC_LONIUID           SUBJID  \
# 0  1016  033_S_1016  ADNI3     m156      y2      1262194  ADNI_033_S_1016
# 1  1016  033_S_1016  ADNI3     m132    init       943663  ADNI_033_S_1016
# 2  1052  141_S_1052  ADNI3     m138      y1      1028474  ADNI_141_S_1052
# 3  1052  141_S_1052  ADNI3     m150      y2      1146953  ADNI_141_S_1052
# 4  1052  141_S_1052  ADNI3     m174      y4      1478681  ADNI_141_S_1052
#
#    PHC_Visit  PHC_Age_Cognition  PHC_Age_DTI  ...  assortativity  \
# 0       13.0          91.485284    91.507187  ...            NaN
# 1       12.0          89.511294    89.514031  ...       0.002719
# 2       12.0          80.684463    80.736482  ...            NaN
# 3       13.0          81.404517    81.393566  ...       0.104106
# 4       14.0          83.750856    83.770021  ...       0.026153
#
#    participation  clustering  nodal_strength  local_efficiency  \
# 0       0.253780  216.401096     99330.87603         80.381086
# 1       0.255245  230.297605    100771.93390         81.253954
# 2       0.224208  244.530254    124392.36360        112.156089
# 3       0.242350  426.698468     90097.35537         48.299624
# 4       0.260836  555.988745    100524.09920         52.503244
#
#    global_efficiency   density rich_club path_length  edge_count
# 0          88.489924  0.645041  0.578656   64.081208    3.647565
# 1          89.708460  0.655923  0.604250   64.322748    3.457824
# 2         126.177678  0.921074  0.750763   92.813030    2.629875
# 3          48.794984  0.330716  0.622533   43.831603    3.720359
# 4          52.071860  0.351377  0.637770   51.497565    3.813135
#
# [5 rows x 13771 columns]

# %% [markdown]
# ## **Data Structure**

# %%
# Data types overview
print("DATA TYPES DISTRIBUTION")
print(df.dtypes.value_counts())

# Identify column types
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

print(f"\nNumerical columns: {len(numerical_cols)}")
print(f"Categorical columns: {len(categorical_cols)}")
# Out:
# DATA TYPES DISTRIBUTION
# float64    13754
# int64          9
# object         8
# Name: count, dtype: int64
#
# Numerical columns: 13763
# Categorical columns: 8

# %%
# Basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3026 entries, 0 to 3025
# Columns: 13771 entries, RID to edge_count
# dtypes: float64(13754), int64(9), object(8)
# memory usage: 317.9+ MB

# %% [markdown]
# ### **Finding Missing Values**

# %%
# Calculate missing values
missing_data = pd.DataFrame({
    'Column': df.columns,
    'Missing_Count': df.isnull().sum(),
    'Missing_Percentage': (df.isnull().sum() / len(df) * 100).round(2)
})

missing_data = missing_data[missing_data['Missing_Count'] > 0].sort_values(
    'Missing_Percentage', ascending=False
)

print(f"\MISSING VALUES SUMMARY")
print(f"Total columns with missing values: {len(missing_data)}")
print(f"Total missing values: {df.isnull().sum().sum():,}")
print(f"Overall missingness: {(df.isnull().sum().sum() / (df.shape[0] * df.shape[1]) * 100):.2f}%")

if len(missing_data) > 0:
    print(f"\nTop columns with missing values:")
    display(missing_data.head(20))
else:
    print("\n✓ No missing values detected!")
# Out:
# \MISSING VALUES SUMMARY
# Total columns with missing values: 8954
# Total missing values: 617,510
# Overall missingness: 1.48%
#
# Top columns with missing values:
#                                                                                                Column  \
# t1seg_3rd_ventricle_fwcorrected_rd_median                   t1seg_3rd_ventricle_fwcorrected_rd_median
# t1seg_3rd_ventricle_fwcorrected_ad_median                   t1seg_3rd_ventricle_fwcorrected_ad_median
# t1seg_3rd_ventricle_fwcorrected_md_median                   t1seg_3rd_ventricle_fwcorrected_md_median
# t1seg_3rd_ventricle_fwcorrected_fa_median                   t1seg_3rd_ventricle_fwcorrected_fa_median
# t1seg_right_lateral_ventricle_fwcorrected_ad_me...  t1seg_right_lateral_ventricle_fwcorrected_ad_m...
# t1seg_right_lateral_ventricle_fwcorrected_rd_me...  t1seg_right_lateral_ventricle_fwcorrected_rd_m...
# t1seg_right_lateral_ventricle_fwcorrected_md_me...  t1seg_right_lateral_ventricle_fwcorrected_md_m...
# t1seg_right_lateral_ventricle_fwcorrected_fa_me...  t1seg_right_lateral_ventricle_fwcorrected_fa_m...
# t1seg_left_lateral_ventricle_fwcorrected_rd_median  t1seg_left_lateral_ventricle_fwcorrected_rd_me...
# t1seg_left_lateral_ventricle_fwcorrected_md_median  t1seg_left_lateral_ventricle_fwcorrected_md_me...
# t1seg_left_lateral_ventricle_fwcorrected_fa_median  t1seg_left_lateral_ventricle_fwcorrected_fa_me...
# t1seg_left_lateral_ventricle_fwcorrected_ad_median  t1seg_left_lateral_ventricle_fwcorrected_ad_me...
# t1seg_posteriorfossa_fwcorrected_md_median                 t1seg_posteriorfossa_fwcorrected_md_median
# t1seg_posteriorfossa_fwcorrected_fa_median                 t1seg_posteriorfossa_fwcorrected_fa_median
# t1seg_posteriorfossa_fwcorrected_rd_median                 t1seg_posteriorfossa_fwcorrected_rd_median
# t1seg_posteriorfossa_fwcorrected_ad_median                 t1seg_posteriorfossa_fwcorrected_ad_median
# t1seg_4th_ventricle_fwcorrected_rd_median                   t1seg_4th_ventricle_fwcorrected_rd_median
# t1seg_4th_ventricle_fwcorrected_ad_median                   t1seg_4th_ventricle_fwcorrected_ad_median
# t1seg_4th_ventricle_fwcorrected_fa_median                   t1seg_4th_ventricle_fwcorrected_fa_median
# t1seg_4th_ventricle_fwcorrected_md_median                   t1seg_4th_ventricle_fwcorrected_md_median
#
#                                                     Missing_Count  \
# t1seg_3rd_ventricle_fwcorrected_rd_median                    3026
# t1seg_3rd_ventricle_fwcorrected_ad_median                    3026
# t1seg_3rd_ventricle_fwcorrected_md_median                    3026
# t1seg_3rd_ventricle_fwcorrected_fa_median                    3026
# t1seg_right_lateral_ventricle_fwcorrected_ad_me...           3026
# t1seg_right_lateral_ventricle_fwcorrected_rd_me...           3026
# t1seg_right_lateral_ventricle_fwcorrected_md_me...           3026
# t1seg_right_lateral_ventricle_fwcorrected_fa_me...           3026
# t1seg_left_lateral_ventricle_fwcorrected_rd_median           3021
# t1seg_left_lateral_ventricle_fwcorrected_md_median           3021
# t1seg_left_lateral_ventricle_fwcorrected_fa_median           3021
# t1seg_left_lateral_ventricle_fwcorrected_ad_median           3021
# t1seg_posteriorfossa_fwcorrected_md_median                   3002
# t1seg_posteriorfossa_fwcorrected_fa_median                   3002
# t1seg_posteriorfossa_fwcorrected_rd_median                   3002
# t1seg_posteriorfossa_fwcorrected_ad_median                   3002
# t1seg_4th_ventricle_fwcorrected_rd_median                    2926
# t1seg_4th_ventricle_fwcorrected_ad_median                    2926
# t1seg_4th_ventricle_fwcorrected_fa_median                    2926
# t1seg_4th_ventricle_fwcorrected_md_median                    2926
#
#                                                     Missing_Percentage
# t1seg_3rd_ventricle_fwcorrected_rd_median                       100.00
# t1seg_3rd_ventricle_fwcorrected_ad_median                       100.00
# t1seg_3rd_ventricle_fwcorrected_md_median                       100.00
# t1seg_3rd_ventricle_fwcorrected_fa_median                       100.00
# t1seg_right_lateral_ventricle_fwcorrected_ad_me...              100.00
# t1seg_right_lateral_ventricle_fwcorrected_rd_me...              100.00
# t1seg_right_lateral_ventricle_fwcorrected_md_me...              100.00
# t1seg_right_lateral_ventricle_fwcorrected_fa_me...              100.00
# t1seg_left_lateral_ventricle_fwcorrected_rd_median               99.83
# t1seg_left_lateral_ventricle_fwcorrected_md_median               99.83
# t1seg_left_lateral_ventricle_fwcorrected_fa_median               99.83
# t1seg_left_lateral_ventricle_fwcorrected_ad_median               99.83
# t1seg_posteriorfossa_fwcorrected_md_median                       99.21
# t1seg_posteriorfossa_fwcorrected_fa_median                       99.21
# t1seg_posteriorfossa_fwcorrected_rd_median                       99.21
# t1seg_posteriorfossa_fwcorrected_ad_median                       99.21
# t1seg_4th_ventricle_fwcorrected_rd_median                        96.70
# t1seg_4th_ventricle_fwcorrected_ad_median                        96.70
# t1seg_4th_ventricle_fwcorrected_fa_median                        96.70
# t1seg_4th_ventricle_fwcorrected_md_median                        96.70

# %%
# Visualize missing values pattern
if len(missing_data) > 0:
    top_missing = missing_data.head(20)

    plt.figure(figsize=(12, 8))
    plt.barh(range(len(top_missing)), top_missing['Missing_Percentage'])
    plt.yticks(range(len(top_missing)), top_missing['Column'])
    plt.xlabel('Missing Percentage (%)')
    plt.title('Top Columns with Missing Values')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Duplicate Detection and Removal**

# %%
# Check for duplicate rows
print("\DUPLICATE DETECTION")
print(f"Original dataset: {df.shape[0]:,} rows × {df.shape[1]:,} columns")

# Check complete duplicate rows
complete_dups = df.duplicated().sum()
print(f"\nComplete duplicate rows: {complete_dups:,}")

# Check duplicates based on patient identifiers
if 'RID' in df.columns:
    rid_dups = df.duplicated(subset=['RID']).sum()
    print(f"Duplicate RID entries: {rid_dups:,}")

if 'RID' in df.columns and 'VISCODE' in df.columns:
    rid_visit_dups = df.duplicated(subset=['RID', 'VISCODE']).sum()
    print(f"Duplicate RID+VISCODE entries: {rid_visit_dups:,}")

if 'PTID' in df.columns and 'VISCODE' in df.columns:
    ptid_visit_dups = df.duplicated(subset=['PTID', 'VISCODE']).sum()
    print(f"Duplicate PTID+VISCODE entries: {ptid_visit_dups:,}")
# Out:
# \DUPLICATE DETECTION
# Original dataset: 3,026 rows × 13,771 columns
#
# Complete duplicate rows: 0
# Duplicate RID entries: 1,775
# Duplicate RID+VISCODE entries: 0
# Duplicate PTID+VISCODE entries: 0

# %%
# Show examples of duplicate entries
if 'RID' in df.columns and 'VISCODE' in df.columns:
    dup_mask = df.duplicated(subset=['RID', 'VISCODE'], keep=False)

    if dup_mask.sum() > 0:
        print("\n📋 EXAMPLE DUPLICATE ENTRIES (RID + VISCODE):")


        # Show identifier columns plus a few key columns
        display_cols = ['RID', 'PTID', 'VISCODE', 'PHC_Visit', 'PHC_Age_DTI']
        display_cols = [col for col in display_cols if col in df.columns]

        dup_examples = df[dup_mask][display_cols].sort_values(['RID', 'VISCODE']).head(20)
        display(dup_examples)

        # Count how many RID+VISCODE combinations are duplicated
        dup_combos = df[dup_mask].groupby(['RID', 'VISCODE']).size()
        print(f"\nNumber of duplicated RID+VISCODE combinations: {len(dup_combos)}")
        print(f"Maximum duplicates for one combination: {dup_combos.max()}")
    else:
        print("\n✓ No duplicate RID+VISCODE entries found.")
# Out:
# ✓ No duplicate RID+VISCODE entries found.

# %%
# Remove duplicates
print("\n🧹 REMOVING DUPLICATES")
print("=" * 60)

# Strategy: Keep one scan per patient per visit

if 'RID' in df.columns and 'VISCODE' in df.columns:
    print("Strategy: Keeping one scan per patient per visit (RID + VISCODE)")
    df_clean = df.drop_duplicates(subset=['RID', 'VISCODE'], keep='first')
elif 'RID' in df.columns:
    print("Strategy: Keeping one scan per patient (RID only)")
    df_clean = df.drop_duplicates(subset=['RID'], keep='first')
else:
    print("Strategy: Removing complete duplicate rows")
    df_clean = df.drop_duplicates()

# Reset index
df_clean = df_clean.reset_index(drop=True)

# Report results
rows_removed = df.shape[0] - df_clean.shape[0]
print(f"\nCleaned dataset: {df_clean.shape[0]:,} rows × {df_clean.shape[1]:,} columns")
print(f"Rows removed: {rows_removed:,}")
print(f"Percentage removed: {(rows_removed / df.shape[0] * 100):.2f}%")

if rows_removed > 0:
    print("\n✓ Duplicates removed successfully!")
    print("\n⚠️  NOTE: Using df_clean for all subsequent analysis")
else:
    print("\n✓ No duplicates found - dataset already clean!")

# Use df_clean for all subsequent analyses
df = df_clean
# Out:
# 🧹 REMOVING DUPLICATES
# ============================================================
# Strategy: Keeping one scan per patient per visit (RID + VISCODE)
#
# Cleaned dataset: 3,026 rows × 13,771 columns
# Rows removed: 0
# Percentage removed: 0.00%
#
# ✓ No duplicates found - dataset already clean!

# %% [markdown]
# # **Summary**

# %%
# Comprehensive summary statistics
if len(numerical_cols) > 0:
    summary_stats = df[numerical_cols].describe().T
    summary_stats['missing'] = df[numerical_cols].isnull().sum()
    summary_stats['missing_pct'] = (df[numerical_cols].isnull().sum() / len(df) * 100).round(2)
    summary_stats['skewness'] = df[numerical_cols].skew().round(2)
    summary_stats['kurtosis'] = df[numerical_cols].kurtosis().round(2)

    print("\n📈 NUMERICAL FEATURES SUMMARY")
    print("=" * 60)
    display(summary_stats.head(20))
# Out:
# 📈 NUMERICAL FEATURES SUMMARY
# ============================================================
#                                               count           mean  \
# RID                                          3026.0    5001.031064
# PHC_LONIUID                                  3026.0  917536.706543
# PHC_Visit                                    1925.0       4.817662
# PHC_Age_Cognition                            3026.0      74.548274
# PHC_Age_DTI                                  3026.0      74.576583
# PHC_Diagnosis                                2550.0       1.645098
# PHC_Sex                                      3026.0       1.479841
# PHC_Race                                     3026.0       4.818903
# PHC_Ethnicity                                3005.0       1.938436
# PHC_Education                                3026.0      16.294779
# Imaging_Site                                 3026.0      94.093853
# FieldStrength                                3026.0       3.000000
# RepetitionTime                               3026.0       9.146306
# EchoTime                                     3026.0       0.069735
# FlipAngle                                    3026.0      90.000000
# PixelSpacing_X                               3026.0       1.620462
# PixelSpacing_Y                               3026.0       1.620462
# SliceThickness                               3026.0       2.250198
# NumberOfDiffusionDirections                  3026.0      56.850297
# PHC_jhu_superior_parietal_wm_left_fa_median  2982.0       0.433494
#
#                                                        std            min  \
# RID                                            1616.613072      21.000000
# PHC_LONIUID                                  442595.958167  189995.000000
# PHC_Visit                                         3.169583       1.000000
# PHC_Age_Cognition                                 7.543572      50.450376
# PHC_Age_DTI                                       7.542653      50.532512
# PHC_Diagnosis                                     0.691203       1.000000
# PHC_Sex                                           0.499676       1.000000
# PHC_Race                                          0.692524       1.000000
# PHC_Ethnicity                                     0.240402       1.000000
# PHC_Education                                     2.572779       8.000000
# Imaging_Site                                    153.622036       2.000000
# FieldStrength                                     0.000000       3.000000
# RepetitionTime                                    3.210025       3.400000
# EchoTime                                          0.013538       0.047700
# FlipAngle                                         0.000000      90.000000
# PixelSpacing_X                                    0.463336       0.906300
# PixelSpacing_Y                                    0.463336       0.906300
# SliceThickness                                    0.345064       1.999603
# NumberOfDiffusionDirections                      27.645089      15.000000
# PHC_jhu_superior_parietal_wm_left_fa_median       0.048253       0.161963
#
#                                                        25%           50%  \
# RID                                            4336.250000  5.017500e+03
# PHC_LONIUID                                  393786.750000  1.003314e+06
# PHC_Visit                                         2.000000  4.000000e+00
# PHC_Age_Cognition                                69.407940  7.452977e+01
# PHC_Age_DTI                                      69.424367  7.455578e+01
# PHC_Diagnosis                                     1.000000  2.000000e+00
# PHC_Sex                                           1.000000  1.000000e+00
# PHC_Race                                          5.000000  5.000000e+00
# PHC_Ethnicity                                     2.000000  2.000000e+00
# PHC_Education                                    14.000000  1.600000e+01
# Imaging_Site                                     22.000000  5.200000e+01
# FieldStrength                                     3.000000  3.000000e+00
# RepetitionTime                                    7.200000  9.050000e+00
# EchoTime                                          0.060400  6.830000e-02
# FlipAngle                                        90.000000  9.000000e+01
# PixelSpacing_X                                    1.367200  1.367200e+00
# PixelSpacing_Y                                    1.367200  1.367200e+00
# SliceThickness                                    2.000000  2.000000e+00
# NumberOfDiffusionDirections                      46.000000  4.600000e+01
# PHC_jhu_superior_parietal_wm_left_fa_median       0.406971  4.370296e-01
#
#                                                       75%           max  \
# RID                                          6.369000e+03  7.115000e+03
# PHC_LONIUID                                  1.270046e+06  1.644377e+06
# PHC_Visit                                    7.000000e+00  1.600000e+01
# PHC_Age_Cognition                            7.968720e+01  9.597536e+01
# PHC_Age_DTI                                  7.969815e+01  9.597536e+01
# PHC_Diagnosis                                2.000000e+00  3.000000e+00
# PHC_Sex                                      2.000000e+00  2.000000e+00
# PHC_Race                                     5.000000e+00  6.000000e+00
# PHC_Ethnicity                                2.000000e+00  2.000000e+00
# PHC_Education                                1.800000e+01  2.000000e+01
# Imaging_Site                                 1.270000e+02  9.410000e+02
# FieldStrength                                3.000000e+00  3.000000e+00
# RepetitionTime                               1.119900e+01  1.773200e+01
# EchoTime                                     7.470000e-02  1.112600e-01
# FlipAngle                                    9.000000e+01  9.000000e+01
# PixelSpacing_X                               2.000000e+00  3.000000e+00
# PixelSpacing_Y                               2.000000e+00  3.000000e+00
# SliceThickness                               2.699997e+00  4.000000e+00
# NumberOfDiffusionDirections                  5.500000e+01  1.270000e+02
# PHC_jhu_superior_parietal_wm_left_fa_median  4.642331e-01  6.081547e-01
#
#                                              missing  missing_pct  skewness  \
# RID                                                0         0.00     -0.98
# PHC_LONIUID                                        0         0.00     -0.19
# PHC_Visit                                       1101        36.38      1.07
# PHC_Age_Cognition                                  0         0.00      0.01
# PHC_Age_DTI                                        0         0.00      0.01
# PHC_Diagnosis                                    476        15.73      0.60
# PHC_Sex                                            0         0.00      0.08
# PHC_Race                                           0         0.00     -2.99
# PHC_Ethnicity                                     21         0.69     -3.65
# PHC_Education                                      0         0.00     -0.35
# Imaging_Site                                       0         0.00      4.54
# FieldStrength                                      0         0.00      0.00
# RepetitionTime                                     0         0.00      0.13
# EchoTime                                           0         0.00      1.06
# FlipAngle                                          0         0.00      0.00
# PixelSpacing_X                                     0         0.00     -0.01
# PixelSpacing_Y                                     0         0.00     -0.01
# SliceThickness                                     0         0.00      0.78
# NumberOfDiffusionDirections                        0         0.00      1.86
# PHC_jhu_superior_parietal_wm_left_fa_median       44         1.45     -0.83
#
#                                              kurtosis
# RID                                              0.55
# PHC_LONIUID                                     -1.33
# PHC_Visit                                        0.50
# PHC_Age_Cognition                               -0.21
# PHC_Age_DTI                                     -0.21
# PHC_Diagnosis                                   -0.77
# PHC_Sex                                         -1.99
# PHC_Race                                         8.87
# PHC_Ethnicity                                   11.33
# PHC_Education                                   -0.64
# Imaging_Site                                    22.19
# FieldStrength                                    0.00
# RepetitionTime                                  -0.07
# EchoTime                                         0.15
# FlipAngle                                        0.00
# PixelSpacing_X                                  -0.83
# PixelSpacing_Y                                  -0.83
# SliceThickness                                  -0.83
# NumberOfDiffusionDirections                      2.22
# PHC_jhu_superior_parietal_wm_left_fa_median      2.66

# %% [markdown]
# # **Categorical Variables Analysis**

# %%
# Analyze categorical variables
if len(categorical_cols) > 0:
    print("\n📋 CATEGORICAL VARIABLES")
    print("=" * 60)

    for col in categorical_cols[:10]:  # Show first 10
        n_unique = df[col].nunique()
        print(f"\n{col}:")
        print(f"  Unique values: {n_unique}")

        if n_unique <= 20:
            print(f"  Value counts:")
            print(df[col].value_counts())
        else:
            print(f"  Top 10 values:")
            print(df[col].value_counts().head(10))
# Out:
# 📋 CATEGORICAL VARIABLES
# ============================================================
#
# PTID:
#   Unique values: 1251
#   Top 10 values:
# PTID
# 027_S_2245    14
# 127_S_2234    13
# 027_S_4869    12
# 127_S_4210    12
# 027_S_4919    11
# 126_S_4891    11
# 027_S_2219    11
# 003_S_4354    10
# 126_S_4514    10
# 007_S_4387     9
# Name: count, dtype: int64
#
# PHASE:
#   Unique values: 3
#   Value counts:
# PHASE
# ADNI3     1980
# ADNI2      949
# ADNIGO      97
# Name: count, dtype: int64
#
# VISCODE2:
#   Unique values: 35
#   Top 10 values:
# VISCODE2
# sc       704
# m12      353
# m24      319
# scmri    236
# m03      187
# m48      163
# m06      160
# m72       98
# m36       84
# m66       66
# Name: count, dtype: int64
#
# VISCODE:
#   Unique values: 20
#   Value counts:
# VISCODE
# sc       704
# y2       398
# y1       332
# init     293
# v02      198
# v11      171
# v04      160
# y4       157
# v21      151
# v05      133
# y3        83
# v41       50
# v31       47
# scmri     38
# v06       30
# m03       27
# m06       27
# y5        13
# v51        9
# m12        5
# Name: count, dtype: int64
#
# SUBJID:
#   Unique values: 987
#   Top 10 values:
# SUBJID
# ADNI_027_S_2245    14
# ADNI_127_S_2234    13
# ADNI_127_S_4210    12
# G-ADNI-AN000132    12
# G-ADNI-AN000138    11
# G-ADNI-AN000114    11
# ADNI_027_S_2219    11
# ADNI_003_S_4354    10
# ADNI_126_S_4514    10
# ADNI_007_S_4387     9
# Name: count, dtype: int64
#
# PHC_SCANDATE:
#   Unique values: 1682
#   Top 10 values:
# PHC_SCANDATE
# 07/06/2018    9
# 04/22/2014    8
# 06/11/2019    7
# 07/16/2018    7
# 11/30/2017    6
# 10/03/2017    6
# 07/23/2020    6
# 10/31/2017    6
# 08/15/2018    6
# 08/27/2019    6
# Name: count, dtype: int64
#
# Manufacturer:
#   Unique values: 3
#   Value counts:
# Manufacturer
# GE         1561
# Siemens    1198
# Philips     267
# Name: count, dtype: int64
#
# Model:
#   Unique values: 15
#   Value counts:
# Model
# DISCOVERY       1050
# Prisma_fit       600
# Signa            433
# Prisma           227
# Skyra            165
# Achieva          153
# Ingenia          105
# Verio            101
# SIGNA             78
# TrioTim           64
# Skyra_fit         16
# MAGNETOM          13
# Biograph_mMR      11
# Intera             9
# DicomCleaner       1
# Name: count, dtype: int64

# %% [markdown]
# # **Identify Potential Target Variable**

# %%
# Identify the target variable (cognitive status/diagnosis)
possible_targets = ['DIAGNOSIS']

target_col = None
for col in df.columns:
    if col in possible_targets or 'DX' in col.upper():
        if df[col].nunique() > 1 and df[col].nunique() < 10:  # Reasonable number of classes
            print(f"Found potential target: {col}")
            print(f"  Unique values: {df[col].unique()}")
            print(f"  Value counts:\n{df[col].value_counts()}\n")

# Manual selection (update this based on the output above)
print("\nPlease identify the correct diagnosis/cognitive status column from above.")
print("Common ADNI diagnosis codes:")
print("  - CN: Cognitively Normal")
print("  - MCI: Mild Cognitive Impairment")
print("  - AD/Dementia: Alzheimer's Disease")
# Out:
# Please identify the correct diagnosis/cognitive status column from above.
# Common ADNI diagnosis codes:
#   - CN: Cognitively Normal
#   - MCI: Mild Cognitive Impairment
#   - AD/Dementia: Alzheimer's Disease

# %%
TARGET_COLUMN = 'PHC_Diagnosis'
# Verify target column exists
if TARGET_COLUMN not in df.columns:
    print(f"❌ Column '{TARGET_COLUMN}' not found. Please check the column name.")
    print(f"Available columns containing 'DIAGNOSIS': {[col for col in df.columns if 'DIAGNOSIS' in col.upper()]}")
else:
    print(f"Target column set: {TARGET_COLUMN}")
    print(f"\nClass distribution:")
    print(df[TARGET_COLUMN].value_counts())
    print(f"\nClass proportions:")
    print(df[TARGET_COLUMN].value_counts(normalize=True).round(3))
# Out:
# Target column set: PHC_Diagnosis
#
# Class distribution:
# PHC_Diagnosis
# 1.0    1222
# 2.0    1011
# 3.0     317
# Name: count, dtype: int64
#
# Class proportions:
# PHC_Diagnosis
# 1.0    0.479
# 2.0    0.396
# 3.0    0.124
# Name: proportion, dtype: float64

# %%
print("🔍 CHECKING DIAGNOSIS CODE MAPPING")
print("=" * 60)

# Step 1: Show unique numeric diagnosis codes
print("\nUnique values in PHC_Diagnosis:")
print(sorted(df['PHC_Diagnosis'].unique()))

# Step 2: Search for possible text diagnosis columns
possible_text_cols = [
    col for col in df.columns
    if df[col].dtype == 'object' and df[col].nunique() <= 10
]

print("\nPossible categorical diagnosis columns found:")
print(possible_text_cols)

# Step 3: Cross-tabulate numeric codes with possible text columns
for col in possible_text_cols:
    print(f"\nCross-tabulation between PHC_Diagnosis and {col}:")
    print(pd.crosstab(df['PHC_Diagnosis'], df[col]))
    print("-" * 60)
# Out:
# 🔍 CHECKING DIAGNOSIS CODE MAPPING
# ============================================================
#
# Unique values in PHC_Diagnosis:
# [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(nan)]
#
# Possible categorical diagnosis columns found:
# ['PHASE', 'Manufacturer']
#
# Cross-tabulation between PHC_Diagnosis and PHASE:
# PHASE          ADNI2  ADNI3  ADNIGO
# PHC_Diagnosis
# 1.0              198   1023       1
# 2.0              268    712      31
# 3.0              121    196       0
# ------------------------------------------------------------
#
# Cross-tabulation between PHC_Diagnosis and Manufacturer:
# Manufacturer    GE  Philips  Siemens
# PHC_Diagnosis
# 1.0            449      114      659
# 2.0            495      119      397
# 3.0            179       29      109
# ------------------------------------------------------------

# %%
# Define feature groups

# Demographic features
demographic_features = []
for col in df.columns:
    col_lower = col.lower()
    if any(keyword in col_lower for keyword in ['age', 'sex', 'gender', 'education', 'ethnicity', 'race', 'apoe']):
        demographic_features.append(col)

print(f"Identified Demographic Features ({len(demographic_features)}):")
print(demographic_features)

# DTI-specific features (fractional anisotropy, mean diffusivity, etc.)
dti_keywords = ['fa', 'md', 'rd', 'ad', 'dti', 'tract', 'diffusion',
                'anisotropy', 'diffusivity', 'fiber', 'white_matter',
                'assortativity', 'participation', 'clustering', 'nodal_strength',
                'efficiency', 'density', 'rich_club', 'path_length', 'edge_count']

dti_features = []
for col in df.columns:
    col_lower = col.lower()
    if any(keyword in col_lower for keyword in dti_keywords):
        if col != TARGET_COLUMN and col not in demographic_features:
            dti_features.append(col)

print(f"\nIdentified DTI Features ({len(dti_features)}):")
print(f"First 20 DTI features: {dti_features[:20]}")

# Identifier columns to exclude
id_columns = ['RID', 'PTID', 'SUBJID', 'PHASE', 'VISCODE', 'VISCODE2',
              'PHC_LONIUID', 'PHC_Visit']

print(f"\nIdentifier columns to exclude: {id_columns}")
# Out:
# Identified Demographic Features (6):
# ['PHC_Age_Cognition', 'PHC_Age_DTI', 'PHC_Sex', 'PHC_Race', 'PHC_Ethnicity', 'PHC_Education']
#
# Identified DTI Features (11015):
# First 20 DTI features: ['Manufacturer', 'NumberOfDiffusionDirections', 'PHC_jhu_superior_parietal_wm_left_fa_median', 'PHC_jhu_superior_parietal_wm_left_fa_mean', 'PHC_jhu_superior_parietal_wm_left_fa_std', 'PHC_jhu_superior_parietal_wm_left_md_median', 'PHC_jhu_superior_parietal_wm_left_md_mean', 'PHC_jhu_superior_parietal_wm_left_md_std', 'PHC_jhu_superior_parietal_wm_left_ad_median', 'PHC_jhu_superior_parietal_wm_left_ad_mean', 'PHC_jhu_superior_parietal_wm_left_ad_std', 'PHC_jhu_superior_parietal_wm_left_rd_median', 'PHC_jhu_superior_parietal_wm_left_rd_mean', 'PHC_jhu_superior_parietal_wm_left_rd_std', 'PHC_jhu_caudate_nucleus_left_fa_median', 'PHC_jhu_caudate_nucleus_left_fa_mean', 'PHC_jhu_caudate_nucleus_left_fa_std', 'PHC_jhu_caudate_nucleus_left_md_median', 'PHC_jhu_caudate_nucleus_left_md_std', 'PHC_jhu_caudate_nucleus_left_ad_median']
#
# Identifier columns to exclude: ['RID', 'PTID', 'SUBJID', 'PHASE', 'VISCODE', 'VISCODE2', 'PHC_LONIUID', 'PHC_Visit']

# %% [markdown]
# # **Distribution Analysis**

# %%
# Plot distributions for selected features
if len(numerical_cols) > 0:
    # Select first 16 numerical columns
    cols_to_plot = numerical_cols[:16]

    fig, axes = plt.subplots(4, 4, figsize=(16, 14))
    axes = axes.flatten()

    for idx, col in enumerate(cols_to_plot):
        ax = axes[idx]
        df[col].hist(bins=30, ax=ax, edgecolor='black', alpha=0.7, color='steelblue')
        ax.set_title(f'{col}\n(Skew: {df[col].skew():.2f})', fontsize=9)
        ax.set_xlabel('')
        ax.set_ylabel('Frequency', fontsize=8)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Correlation Analysis**

# %%
# Calculate correlation matrix
if len(numerical_cols) > 1:
    print("\n🔗 CORRELATION ANALYSIS")
    print("=" * 60)

    # For large datasets, sample columns for correlation analysis
    cols_for_corr = numerical_cols[:100] if len(numerical_cols) > 100 else numerical_cols

    correlation_matrix = df[cols_for_corr].corr()

    # Find highly correlated pairs
    high_corr = []
    for i in range(len(correlation_matrix.columns)):
        for j in range(i+1, len(correlation_matrix.columns)):
            corr_value = correlation_matrix.iloc[i, j]
            if abs(corr_value) > 0.8:  # High correlation threshold
                high_corr.append({
                    'Feature_1': correlation_matrix.columns[i],
                    'Feature_2': correlation_matrix.columns[j],
                    'Correlation': round(corr_value, 3)
                })

    if high_corr:
        high_corr_df = pd.DataFrame(high_corr).sort_values(
            'Correlation', key=abs, ascending=False
        )
        print(f"\nHighly correlated pairs (|r| > 0.8): {len(high_corr_df)}")
        display(high_corr_df.head(20))
    else:
        print("\nNo highly correlated pairs found (|r| > 0.8).")
# Out:
# 🔗 CORRELATION ANALYSIS
# ============================================================
#
# Highly correlated pairs (|r| > 0.8): 118
#                                        Feature_1  \
# 1                              PHC_Age_Cognition
# 2                                 PixelSpacing_X
# 29        PHC_jhu_caudate_nucleus_left_md_median
# 28        PHC_jhu_caudate_nucleus_left_md_median
# 33        PHC_jhu_caudate_nucleus_left_ad_median
# 32           PHC_jhu_caudate_nucleus_left_md_std
# 17      PHC_jhu_superior_parietal_wm_left_md_std
# 68         PHC_jhu_middle_frontal_wm_left_md_std
# 108            PHC_jhu_precentral_wm_left_md_std
# 46       PHC_jhu_superior_frontal_wm_left_md_std
# 91       PHC_jhu_inferior_frontal_wm_left_md_std
# 66        PHC_jhu_middle_frontal_wm_left_md_mean
# 31           PHC_jhu_caudate_nucleus_left_md_std
# 15     PHC_jhu_superior_parietal_wm_left_md_mean
# 76    PHC_jhu_inferior_frontal_wm_left_fa_median
# 106           PHC_jhu_precentral_wm_left_md_mean
# 37    PHC_jhu_superior_frontal_wm_left_fa_median
# 89      PHC_jhu_inferior_frontal_wm_left_md_mean
# 3    PHC_jhu_superior_parietal_wm_left_fa_median
# 22        PHC_jhu_caudate_nucleus_left_fa_median
#
#                                      Feature_2  Correlation
# 1                                  PHC_Age_DTI        1.000
# 2                               PixelSpacing_Y        1.000
# 29      PHC_jhu_caudate_nucleus_left_rd_median        0.999
# 28      PHC_jhu_caudate_nucleus_left_ad_median        0.998
# 33      PHC_jhu_caudate_nucleus_left_rd_median        0.995
# 32         PHC_jhu_caudate_nucleus_left_rd_std        0.995
# 17    PHC_jhu_superior_parietal_wm_left_rd_std        0.994
# 68       PHC_jhu_middle_frontal_wm_left_rd_std        0.994
# 108          PHC_jhu_precentral_wm_left_rd_std        0.994
# 46     PHC_jhu_superior_frontal_wm_left_rd_std        0.991
# 91     PHC_jhu_inferior_frontal_wm_left_rd_std        0.987
# 66      PHC_jhu_middle_frontal_wm_left_rd_mean        0.984
# 31         PHC_jhu_caudate_nucleus_left_ad_std        0.982
# 15   PHC_jhu_superior_parietal_wm_left_rd_mean        0.982
# 76    PHC_jhu_inferior_frontal_wm_left_fa_mean        0.980
# 106         PHC_jhu_precentral_wm_left_rd_mean        0.977
# 37    PHC_jhu_superior_frontal_wm_left_fa_mean        0.976
# 89    PHC_jhu_inferior_frontal_wm_left_rd_mean        0.976
# 3    PHC_jhu_superior_parietal_wm_left_fa_mean        0.974
# 22        PHC_jhu_caudate_nucleus_left_fa_mean        0.971

# %%
# Visualize correlation heatmap (for subset of features)
if len(numerical_cols) > 1:
    # Select subset for visualization
    cols_for_viz = numerical_cols[:10] if len(numerical_cols) > 30 else numerical_cols

    plt.figure(figsize=(10, 8))
    sns.heatmap(
        df[cols_for_viz].corr(),
        cmap='coolwarm',
        center=0,
        vmin=-1,
        vmax=1,
        square=True,
        linewidths=0.5,
        cbar_kws={'shrink': 0.8}
    )
    plt.title(f'Correlation Heatmap (First {len(cols_for_viz)} Features)', fontsize=14, pad=20)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Outlier Detection**

# %%
# Detect outliers using IQR method
print("\n⚠️  OUTLIER DETECTION (IQR Method)")
print("=" * 60)

outlier_summary = []
for col in numerical_cols[:50]:  # Check first 50 columns
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    n_outliers = len(outliers)
    pct_outliers = (n_outliers / len(df) * 100)

    if n_outliers > 0:
        outlier_summary.append({
            'Column': col,
            'N_Outliers': n_outliers,
            'Percentage': round(pct_outliers, 2),
            'Lower_Bound': round(lower_bound, 3),
            'Upper_Bound': round(upper_bound, 3)
        })

if outlier_summary:
    outlier_df = pd.DataFrame(outlier_summary).sort_values('N_Outliers', ascending=False)
    print(f"\nColumns with outliers: {len(outlier_df)}")
    display(outlier_df.head(20))
else:
    print("\n✓ No outliers detected using IQR method.")
# Out:
# ⚠️  OUTLIER DETECTION (IQR Method)
# ============================================================
#
# Columns with outliers: 41
#                                          Column  N_Outliers  Percentage  \
# 12                  NumberOfDiffusionDirections         592       19.56
# 4                                      PHC_Race         321       10.61
# 8                                      EchoTime         193        6.38
# 18     PHC_jhu_superior_parietal_wm_left_md_std         186        6.15
# 5                                 PHC_Ethnicity         185        6.11
# 37      PHC_jhu_superior_frontal_wm_left_md_std         181        5.98
# 21     PHC_jhu_superior_parietal_wm_left_ad_std         179        5.92
# 39      PHC_jhu_superior_frontal_wm_left_ad_std         179        5.92
# 24     PHC_jhu_superior_parietal_wm_left_rd_std         176        5.82
# 6                                  Imaging_Site         138        4.56
# 17    PHC_jhu_superior_parietal_wm_left_md_mean         128        4.23
# 0                                           RID         121        4.00
# 20    PHC_jhu_superior_parietal_wm_left_ad_mean         119        3.93
# 23    PHC_jhu_superior_parietal_wm_left_rd_mean         118        3.90
# 19  PHC_jhu_superior_parietal_wm_left_ad_median         113        3.73
# 16  PHC_jhu_superior_parietal_wm_left_md_median         101        3.34
# 30          PHC_jhu_caudate_nucleus_left_ad_std          98        3.24
# 22  PHC_jhu_superior_parietal_wm_left_rd_median          93        3.07
# 29          PHC_jhu_caudate_nucleus_left_md_std          92        3.04
# 13  PHC_jhu_superior_parietal_wm_left_fa_median          71        2.35
#
#     Lower_Bound  Upper_Bound
# 12       32.500       68.500
# 4         5.000        5.000
# 8         0.039        0.096
# 18        0.000        0.000
# 5         2.000        2.000
# 37       -0.001        0.001
# 21        0.000        0.000
# 39       -0.000        0.001
# 24        0.000        0.000
# 6      -135.500      284.500
# 17        0.001        0.001
# 0      1287.125     9418.125
# 20        0.001        0.001
# 23        0.000        0.001
# 19        0.001        0.001
# 16        0.001        0.001
# 30       -0.001        0.003
# 22        0.000        0.001
# 29       -0.001        0.003
# 13        0.321        0.550

# %% [markdown]
# # **Boxplot Visualization**

# %%
# Create boxplots for selected features
if len(numerical_cols) > 0:
    cols_to_plot = numerical_cols[:12]

    fig, axes = plt.subplots(3, 4, figsize=(16, 12))
    axes = axes.flatten()

    for idx, col in enumerate(cols_to_plot):
        ax = axes[idx]
        df.boxplot(column=col, ax=ax)
        ax.set_title(col, fontsize=10)
        ax.set_xlabel('')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Data Quality Summary**

# %%
print("\n" + "="*70)
print("📊 COMPREHENSIVE DATA QUALITY SUMMARY")
print("="*70)

print(f"\n📐 DATASET DIMENSIONS:")
print(f"  • Total rows: {df.shape[0]:,}")
print(f"  • Total columns: {df.shape[1]:,}")
print(f"  • Numerical features: {len(numerical_cols):,}")
print(f"  • Categorical features: {len(categorical_cols):,}")

print(f"\n🔍 DATA COMPLETENESS:")
print(f"  • Total missing values: {df.isnull().sum().sum():,}")
print(f"  • Missing percentage: {(df.isnull().sum().sum() / (df.shape[0] * df.shape[1]) * 100):.2f}%")
print(f"  • Columns with missing data: {(df.isnull().sum() > 0).sum():,}")

print(f"\n🔄 DATA QUALITY:")
print(f"  • Duplicate rows: {df.duplicated().sum():,}")
if outlier_summary:
    print(f"  • Columns with outliers: {len(outlier_df):,}")

print(f"\n💾 MEMORY USAGE:")
print(f"  • Total memory: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# ======================================================================
# 📊 COMPREHENSIVE DATA QUALITY SUMMARY
# ======================================================================
#
# 📐 DATASET DIMENSIONS:
#   • Total rows: 3,026
#   • Total columns: 13,771
#   • Numerical features: 13,763
#   • Categorical features: 8
#
# 🔍 DATA COMPLETENESS:
#   • Total missing values: 617,510
#   • Missing percentage: 1.48%
#   • Columns with missing data: 8,954
#
# 🔄 DATA QUALITY:
#   • Duplicate rows: 0
#   • Columns with outliers: 41
#
# 💾 MEMORY USAGE:
#   • Total memory: 319.03 MB

# %% [markdown]
# # **Data Preprocessing**

# %%
print("\n🔧 FEATURE SELECTION")
print("=" * 60)

# Columns to EXCLUDE from features
exclude_cols = [
    # ID columns
    'RID', 'PTID', 'PHASE', 'VISCODE2', 'VISCODE',
    'PHC_LONIUID', 'SUBJID', 'PHC_Visit',
    # Target
    'PHC_Diagnosis',
    # Multicollinear with PHC_Age_DTI
    'PHC_Age_Cognition'
]

# Demographic features to KEEP
demographic_features = [
    'PHC_Age_DTI',
    'PHC_Sex',
    'PHC_Race',
    'PHC_Ethnicity',
    'PHC_Education'
]

# Get all numeric columns
all_numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Remove excluded columns
feature_cols = [col for col in all_numeric_cols if col not in exclude_cols]

print(f"\nTotal columns in dataset: {len(df.columns)}")
print(f"Total numeric columns: {len(all_numeric_cols)}")
print(f"Excluded columns: {len(exclude_cols)}")
print(f"Selected features: {len(feature_cols)}")

# Check which demographic features are included
included_demographics = [col for col in demographic_features if col in feature_cols]
print(f"\nDemographic features included: {len(included_demographics)}")
for col in included_demographics:
    print(f"  ✓ {col}")

# Estimate DTI features
dti_features = [col for col in feature_cols if col not in demographic_features]
print(f"\nDTI features: {len(dti_features)}")
print(f"\nFirst 10 DTI features:")
for i, col in enumerate(dti_features[:10], 1):
    print(f"  {i}. {col}")


print("\n✓ Features selected successfully!")
# Out:
# 🔧 FEATURE SELECTION
# ============================================================
#
# Total columns in dataset: 13771
# Total numeric columns: 13763
# Excluded columns: 10
# Selected features: 13758
#
# Demographic features included: 5
#   ✓ PHC_Age_DTI
#   ✓ PHC_Sex
#   ✓ PHC_Race
#   ✓ PHC_Ethnicity
#   ✓ PHC_Education
#
# DTI features: 13753
#
# First 10 DTI features:
#   1. Imaging_Site
#   2. FieldStrength
#   3. RepetitionTime
#   4. EchoTime
#   5. FlipAngle
#   6. PixelSpacing_X
#   7. PixelSpacing_Y
#   8. SliceThickness
#   9. NumberOfDiffusionDirections
#   10. PHC_jhu_superior_parietal_wm_left_fa_median
#
# ✓ Features selected successfully!

# %% [markdown]
# Prepare Features (X) and Target (y)

# %%
print("\n📊 PREPARING FEATURES AND TARGET")
print("=" * 60)

# Extract features (X) and target (y)
X = df[feature_cols].copy()
y = df[TARGET_COLUMN].copy()

print(f"\nFeatures (X): {X.shape}")
print(f"  Demographics: {len(included_demographics)}")
print(f"  DTI features: {len(dti_features)}")

print(f"\nTarget (y): {y.shape}")
print(f"  Unique classes: {y.nunique()}")
print(f"\nClass distribution:")
for label, count in y.value_counts().items():
    pct = (count / len(y)) * 100
    print(f"  {label}: {count:,} ({pct:.1f}%)")

print("\n✓ X and y prepared successfully!")
# Out:
# 📊 PREPARING FEATURES AND TARGET
# ============================================================
#
# Features (X): (3026, 13758)
#   Demographics: 5
#   DTI features: 13753
#
# Target (y): (3026,)
#   Unique classes: 3
#
# Class distribution:
#   1.0: 1,222 (40.4%)
#   2.0: 1,011 (33.4%)
#   3.0: 317 (10.5%)
#
# ✓ X and y prepared successfully!

# %% [markdown]
# Missing Values Analysis

# %%
print("\n🔍 MISSING VALUES ANALYSIS")
print("=" * 60)

# Check missing values in features
missing_counts = df[feature_cols].isnull().sum()
features_with_missing = missing_counts[missing_counts > 0]

print(f"\nFeatures with missing values: {len(features_with_missing)} / {len(feature_cols)}")

if len(features_with_missing) > 0:
    print(f"\nTop 20 features with most missing values:")
    top_missing = features_with_missing.sort_values(ascending=False).head(20)

    for col, count in top_missing.items():
        pct = (count / len(df)) * 100
        print(f"  {col}: {count:,} ({pct:.1f}%)")

    total_missing = df[feature_cols].isnull().sum().sum()
    total_cells = len(df) * len(feature_cols)
    print(f"\nTotal missing: {total_missing:,} / {total_cells:,} ({(total_missing/total_cells)*100:.2f}%)")
    print("\n⚠️  Missing values will be imputed using median strategy")
else:
    print("\n✓ No missing values found!")

# Check missing in demographics specifically
print(f"\n📊 DEMOGRAPHIC FEATURES COMPLETENESS:")
for col in included_demographics:
    missing = df[col].isnull().sum()
    pct = (missing / len(df)) * 100
    status = "✓" if missing == 0 else "⚠️"
    print(f"  {status} {col}: {missing:,} missing ({pct:.1f}%)")
# Out:
# 🔍 MISSING VALUES ANALYSIS
# ============================================================
#
# Features with missing values: 8951 / 13758
#
# Top 20 features with most missing values:
#   t1seg_3rd_ventricle_fwcorrected_ad_median: 3,026 (100.0%)
#   t1seg_3rd_ventricle_fwcorrected_rd_median: 3,026 (100.0%)
#   t1seg_3rd_ventricle_fwcorrected_md_median: 3,026 (100.0%)
#   t1seg_3rd_ventricle_fwcorrected_fa_median: 3,026 (100.0%)
#   t1seg_right_lateral_ventricle_fwcorrected_md_median: 3,026 (100.0%)
#   t1seg_right_lateral_ventricle_fwcorrected_fa_median: 3,026 (100.0%)
#   t1seg_right_lateral_ventricle_fwcorrected_rd_median: 3,026 (100.0%)
#   t1seg_right_lateral_ventricle_fwcorrected_ad_median: 3,026 (100.0%)
#   t1seg_left_lateral_ventricle_fwcorrected_rd_median: 3,021 (99.8%)
#   t1seg_left_lateral_ventricle_fwcorrected_ad_median: 3,021 (99.8%)
#   t1seg_left_lateral_ventricle_fwcorrected_md_median: 3,021 (99.8%)
#   t1seg_left_lateral_ventricle_fwcorrected_fa_median: 3,021 (99.8%)
#   t1seg_posteriorfossa_fwcorrected_ad_median: 3,002 (99.2%)
#   t1seg_posteriorfossa_fwcorrected_md_median: 3,002 (99.2%)
#   t1seg_posteriorfossa_fwcorrected_fa_median: 3,002 (99.2%)
#   t1seg_posteriorfossa_fwcorrected_rd_median: 3,002 (99.2%)
#   t1seg_4th_ventricle_fwcorrected_ad_median: 2,926 (96.7%)
#   t1seg_4th_ventricle_fwcorrected_rd_median: 2,926 (96.7%)
#   t1seg_4th_ventricle_fwcorrected_fa_median: 2,926 (96.7%)
#   t1seg_4th_ventricle_fwcorrected_md_median: 2,926 (96.7%)
#
# Total missing: 615,634 / 41,631,708 (1.48%)
#
# ⚠️  Missing values will be imputed using median strategy
#
# 📊 DEMOGRAPHIC FEATURES COMPLETENESS:
#   ✓ PHC_Age_DTI: 0 missing (0.0%)
#   ✓ PHC_Sex: 0 missing (0.0%)
#   ✓ PHC_Race: 0 missing (0.0%)
#   ⚠️ PHC_Ethnicity: 21 missing (0.7%)
#   ✓ PHC_Education: 0 missing (0.0%)

# %%
print("Missing y:", y.isna().sum())
print("y value counts (after drop):")
print(y.value_counts())
# Out:
# Missing y: 476
# y value counts (after drop):
# PHC_Diagnosis
# 1.0    1222
# 2.0    1011
# 3.0     317
# Name: count, dtype: int64

# %% [markdown]
# Train-Test Split (80/20)

# %%
# Combine X and y to drop matching rows safely
data = pd.concat([X, y], axis=1)

# Drop rows where target is missing
data = data.dropna(subset=[y.name])

# Split back into X and y
X = data.drop(columns=[y.name])
y = data[y.name]

print(f"Remaining samples after removing NaNs: {len(y):,}")
print(f"Remaining NaNs in y: {y.isna().sum()}")
# Out:
# Remaining samples after removing NaNs: 2,550
# Remaining NaNs in y: 0

# %%
print("\n✂️  TRAIN-TEST SPLIT")
print("=" * 60)

# Split configuration
TEST_SIZE = 0.2
RANDOM_STATE = 42

# Perform stratified split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y  # Maintains class distribution
)

print(f"\nSplit ratio: {int((1-TEST_SIZE)*100)}/{int(TEST_SIZE*100)}")
print(f"Random state: {RANDOM_STATE}")
print(f"Stratified: Yes")

print(f"\nTrain set: {X_train.shape[0]:,} samples ({(1-TEST_SIZE)*100:.0f}%)")
print(f"Test set: {X_test.shape[0]:,} samples ({TEST_SIZE*100:.0f}%)")

print(f"\n📊 Train set class distribution:")
for label, count in y_train.value_counts().items():
    pct = (count / len(y_train)) * 100
    print(f"  {label}: {count:,} ({pct:.1f}%)")

print(f"\n📊 Test set class distribution:")
for label, count in y_test.value_counts().items():
    pct = (count / len(y_test)) * 100
    print(f"  {label}: {count:,} ({pct:.1f}%)")

print("\n✓ Data split successfully!")
# Out:
# ✂️  TRAIN-TEST SPLIT
# ============================================================
#
# Split ratio: 80/20
# Random state: 42
# Stratified: Yes
#
# Train set: 2,040 samples (80%)
# Test set: 510 samples (20%)
#
# 📊 Train set class distribution:
#   1.0: 977 (47.9%)
#   2.0: 809 (39.7%)
#   3.0: 254 (12.5%)
#
# 📊 Test set class distribution:
#   1.0: 245 (48.0%)
#   2.0: 202 (39.6%)
#   3.0: 63 (12.4%)
#
# ✓ Data split successfully!

# %% [markdown]
# Encode Target Variable

# %%
print("\n🔤 ENCODING TARGET VARIABLE")
print("=" * 60)

# Check if target needs encoding
if y_train.dtype == 'object' or y_train.dtype.name == 'category':
    print(f"\nTarget type: {y_train.dtype} (needs encoding)")

    # Initialize label encoder
    label_encoder = LabelEncoder()

    # Fit on training data
    y_train_encoded = label_encoder.fit_transform(y_train)
    y_test_encoded = label_encoder.transform(y_test)

    # Show encoding mapping
    print(f"\nClass encoding mapping:")
    for i, label in enumerate(label_encoder.classes_):
        count_train = (y_train_encoded == i).sum()
        print(f"  '{label}' → {i} ({count_train:,} samples in train)")

    # Update y_train and y_test
    y_train = pd.Series(y_train_encoded, name=TARGET_COLUMN, index=y_train.index)
    y_test = pd.Series(y_test_encoded, name=TARGET_COLUMN, index=y_test.index)

    print("\n✓ Target encoded successfully!")
else:
    label_encoder = None
    print(f"\nTarget type: {y_train.dtype} (already numeric)")
    print("\n✓ Target encoding not needed!")

print(f"\nFinal target distribution (train):")
print(y_train.value_counts().sort_index())
# Out:
# 🔤 ENCODING TARGET VARIABLE
# ============================================================
#
# Target type: float64 (already numeric)
#
# ✓ Target encoding not needed!
#
# Final target distribution (train):
# PHC_Diagnosis
# 1.0    977
# 2.0    809
# 3.0    254
# Name: count, dtype: int64

# %%
# ✅ Ensure classes are 0..K-1 (required by XGBoost for multi-class)
y_train = y_train.astype(int)
y_test = y_test.astype(int)

unique_classes = sorted(y_train.unique())
class_map = {old: new for new, old in enumerate(unique_classes)}

y_train = y_train.map(class_map)
y_test = y_test.map(class_map)

print("✅ Remapped target classes:", class_map)
print("Train classes now:", sorted(y_train.unique()))
# Out:
# ✅ Remapped target classes: {np.int64(1): 0, np.int64(2): 1, np.int64(3): 2}
# Train classes now: [np.int64(0), np.int64(1), np.int64(2)]

# %% [markdown]
# Feature Scaling (Standardization)

# %%
print("\n⚖️  CLEANING + IMPUTATION + SCALING")
print("=" * 60)

# 1) Ensure numeric (turn non-numeric into NaN)
X_train_num = X_train.apply(pd.to_numeric, errors="coerce")
X_test_num  = X_test.apply(pd.to_numeric, errors="coerce")

# 2) Replace inf/-inf with NaN
X_train_num = X_train_num.replace([np.inf, -np.inf], np.nan)
X_test_num  = X_test_num.replace([np.inf, -np.inf], np.nan)

# 3) Drop columns that are ALL NaN in TRAIN (they can't be imputed by median)
all_nan_cols = X_train_num.columns[X_train_num.isna().all()]
if len(all_nan_cols) > 0:
    print(f"⚠️ Dropping {len(all_nan_cols)} columns with all-NaN in TRAIN")
    X_train_num = X_train_num.drop(columns=all_nan_cols)
    X_test_num  = X_test_num.drop(columns=all_nan_cols)

# 4) Fill missing values using TRAIN medians (no leakage)
train_medians = X_train_num.median(numeric_only=True)
X_train_num = X_train_num.fillna(train_medians)
X_test_num  = X_test_num.fillna(train_medians)

# 5) Final safety net: if any NaNs still remain, fill with 0 (rare, but prevents crashes)
nans_left_train = X_train_num.isna().sum().sum()
nans_left_test  = X_test_num.isna().sum().sum()
if nans_left_train > 0 or nans_left_test > 0:
    print(f"⚠️ NaNs still found (train={nans_left_train}, test={nans_left_test}). Filling remaining NaNs with 0.")
    X_train_num = X_train_num.fillna(0)
    X_test_num  = X_test_num.fillna(0)

# 6) Scale (fit on train only)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_num)
X_test_scaled  = scaler.transform(X_test_num)

# 7) Put back into DataFrames (IMPORTANT: update X_train/X_test used in training)
feature_cols = X_train_num.columns
X_train = pd.DataFrame(X_train_scaled, columns=feature_cols, index=X_train.index)
X_test  = pd.DataFrame(X_test_scaled,  columns=feature_cols, index=X_test.index)

print("✅ Cleaning + imputation + scaling done.")
print("X_train shape:", X_train.shape, "| NaNs:", X_train.isna().sum().sum())
print("X_test shape :", X_test.shape,  "| NaNs:", X_test.isna().sum().sum())
# Out:
# ⚖️  CLEANING + IMPUTATION + SCALING
# ============================================================
# ⚠️ Dropping 8 columns with all-NaN in TRAIN
# ✅ Cleaning + imputation + scaling done.
# X_train shape: (2040, 13750) | NaNs: 0
# X_test shape : (510, 13750) | NaNs: 0

# %%
bad_cols = np.isinf(X_train_num.to_numpy()).any(axis=0)
print("Columns with inf:", list(X_train_num.columns[bad_cols]))

print("Max values (top 10):")
print(X_train_num.max().sort_values(ascending=False).head(10))
# Out:
# Columns with inf: []
# Max values (top 10):
# t1seg_ticv_volume                               386192.000000
# PHC_t1seg_ticv_volume                           374388.070842
# cc_surface_area                                 307904.000000
# t1seg_right_cerebral_white_matter_volume        297072.000000
# t1seg_left_cerebral_white_matter_volume         295256.000000
# PHC_t1seg_right_cerebral_white_matter_volume    276622.474217
# PHC_t1seg_left_cerebral_white_matter_volume     270933.030717
# cc_volume                                       156630.000000
# nodal_strength                                  134962.472700
# PHC_nodal_strength                              130802.602963
# dtype: float64

# %% [markdown]
# Preprocessing Summary

# %%
label_encoder = None

print("\n" + "="*70)
print("📊 PREPROCESSING PIPELINE SUMMARY")
print("="*70)

print(f"\n✅ COMPLETED STEPS:")
print(f"  1. ✓ Data loaded: {df.shape[0]:,} rows × {df.shape[1]:,} columns")
print(f"  2. ✓ Duplicates removed")
print(f"  3. ✓ Target defined: {TARGET_COLUMN}")
print(f"  4. ✓ Features selected: {len(feature_cols)} features")
print(f"      • Demographics: {len(included_demographics)}")
print(f"      • DTI features: {len(dti_features)}")
print(f"  5. ✓ Missing values: Imputed (median + fallback 0)")
print(f"  6. ✓ Train-test split: {X_train.shape[0]:,} / {X_test.shape[0]:,}")
print(f"  7. ✓ Target encoded: {'Yes' if label_encoder else 'Already numeric'}")
print(f"  8. ✓ Features scaled: StandardScaler")

print(f"\n📐 FINAL DATA SHAPES:")
print(f"  X_train: {X_train.shape}")
print(f"  X_test: {X_test.shape}")
print(f"  y_train: {y_train.shape}")
print(f"  y_test: {y_test.shape}")

print(f"\n🎯 TARGET CLASSES:")
if label_encoder:
    print(f"  Classes: {list(label_encoder.classes_)}")
    print(f"  Encoded as: {list(range(len(label_encoder.classes_)))}")
print(f"\n  Train distribution:")
for class_label, count in y_train.value_counts().sort_index().items():
    pct = (count / len(y_train)) * 100
    if label_encoder:
        original = label_encoder.classes_[class_label]
        print(f"    {original} ({class_label}): {count:,} ({pct:.1f}%)")
    else:
        print(f"    {class_label}: {count:,} ({pct:.1f}%)")

print(f"\n💾 PREPROCESSING OBJECTS CREATED:")
print(f"  • scaler: StandardScaler")
print(f"  • imputer: Median fill (train) + fallback 0")
print(f"  • label_encoder: {'LabelEncoder' if label_encoder else 'None'}")
print(f"  • feature_cols: List of {len(feature_cols)} feature names")

print("\n" + "="*70)
print("✅ PREPROCESSING COMPLETE - READY FOR MODELING!")
print("="*70)
# Out:
# ======================================================================
# 📊 PREPROCESSING PIPELINE SUMMARY
# ======================================================================
#
# ✅ COMPLETED STEPS:
#   1. ✓ Data loaded: 3,026 rows × 13,771 columns
#   2. ✓ Duplicates removed
#   3. ✓ Target defined: PHC_Diagnosis
#   4. ✓ Features selected: 13750 features
#       • Demographics: 5
#       • DTI features: 13753
#   5. ✓ Missing values: Imputed (median + fallback 0)
#   6. ✓ Train-test split: 2,040 / 510
#   7. ✓ Target encoded: Already numeric
#   8. ✓ Features scaled: StandardScaler
#
# 📐 FINAL DATA SHAPES:
#   X_train: (2040, 13750)
#   X_test: (510, 13750)
#   y_train: (2040,)
#   y_test: (510,)
#
# 🎯 TARGET CLASSES:
#
#   Train distribution:
#     0: 977 (47.9%)
#     1: 809 (39.7%)
#     2: 254 (12.5%)
#
# 💾 PREPROCESSING OBJECTS CREATED:
#   • scaler: StandardScaler
#   • imputer: Median fill (train) + fallback 0
#   • label_encoder: None
#   • feature_cols: List of 13750 feature names
#
# ======================================================================
# ✅ PREPROCESSING COMPLETE - READY FOR MODELING!
# ======================================================================

# %% [markdown]
# Visualize Class Distribution

# %%
# Visualize target distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Train set
y_train_counts = y_train.value_counts().sort_index()
if label_encoder:
    labels = [label_encoder.classes_[i] for i in y_train_counts.index]
else:
    labels = y_train_counts.index

axes[0].bar(range(len(y_train_counts)), y_train_counts.values, color='steelblue', edgecolor='black')
axes[0].set_xticks(range(len(y_train_counts)))
axes[0].set_xticklabels(labels, rotation=45)
axes[0].set_title('Train Set Distribution', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Count', fontsize=12)
axes[0].grid(axis='y', alpha=0.3)

# Test set
y_test_counts = y_test.value_counts().sort_index()
if label_encoder:
    labels = [label_encoder.classes_[i] for i in y_test_counts.index]
else:
    labels = y_test_counts.index

axes[1].bar(range(len(y_test_counts)), y_test_counts.values, color='coral', edgecolor='black')
axes[1].set_xticks(range(len(y_test_counts)))
axes[1].set_xticklabels(labels, rotation=45)
axes[1].set_title('Test Set Distribution', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Count', fontsize=12)
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

print("✓ Visualization complete!")
# Out:
# ✓ Visualization complete!

# %% [markdown]
# Initialize Models

# %%
  # Set random seed for reproducibility
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

print("\n🤖 INITIALIZING MODELS")
print("=" * 60)

# Define models
models = {
    'Logistic Regression': LogisticRegression(
        random_state=RANDOM_STATE,
        max_iter=1000,
        n_jobs=-1
    ),

    'Random Forest': RandomForestClassifier(
        n_estimators=100,
        random_state=RANDOM_STATE,
        n_jobs=-1
    ),

    'XGBoost': XGBClassifier(
    n_estimators=100,
    random_state=RANDOM_STATE,
    n_jobs=-1,
    objective="multi:softprob",
    num_class=len(np.unique(y_train)),
    eval_metric="mlogloss"
),
}

print(f"\nModels initialized:")
for name, model in models.items():
    print(f"  ✓ {name}")

print(f"\n✓ {len(models)} models ready for training!")
# Out:
# 🤖 INITIALIZING MODELS
# ============================================================
#
# Models initialized:
#   ✓ Logistic Regression
#   ✓ Random Forest
#   ✓ XGBoost
#
# ✓ 3 models ready for training!

# %% [markdown]
# Train Models

# %%
print("\n🎯 TRAINING MODELS")
print("=" * 60)

import time

# Dictionary to store trained models
trained_models = {}
training_times = {}

for name, model in models.items():
    print(f"\nTraining {name}...")

    # Time the training
    start_time = time.time()
    model.fit(X_train, y_train)
    end_time = time.time()

    training_time = end_time - start_time
    training_times[name] = training_time
    trained_models[name] = model

    print(f"  ✓ Completed in {training_time:.2f} seconds")

print("\n" + "=" * 60)
print("✅ ALL MODELS TRAINED SUCCESSFULLY!")
print("=" * 60)
# Out:
# 🎯 TRAINING MODELS
# ============================================================
#
# Training Logistic Regression...
#   ✓ Completed in 17.64 seconds
#
# Training Random Forest...
#   ✓ Completed in 4.17 seconds
#
# Training XGBoost...
#   ✓ Completed in 170.37 seconds
#
# ============================================================
# ✅ ALL MODELS TRAINED SUCCESSFULLY!
# ============================================================

# %% [markdown]
# Make Predictions

# %%
print("\n🔮 GENERATING PREDICTIONS")
print("=" * 60)

# Store predictions
predictions = {}
probabilities = {}

for name, model in trained_models.items():
    # Predictions
    y_pred = model.predict(X_test)
    predictions[name] = y_pred

    # Probabilities (for ROC curves)
    if hasattr(model, 'predict_proba'):
        y_prob = model.predict_proba(X_test)
        probabilities[name] = y_prob

    print(f"  ✓ {name}: {len(y_pred)} predictions generated")

print("\n✓ Predictions complete!")
# Out:
# 🔮 GENERATING PREDICTIONS
# ============================================================
#   ✓ Logistic Regression: 510 predictions generated
#   ✓ Random Forest: 510 predictions generated
#   ✓ XGBoost: 510 predictions generated
#
# ✓ Predictions complete!

# %% [markdown]
# Evaluate Models

# %%
print("\n📊 MODEL EVALUATION")
print("=" * 60)

# Store results
results = []

for name in trained_models.keys():
    y_pred = predictions[name]

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

    # Store results
    results.append({
        'Model': name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1-Score': f1,
        'Training Time (s)': training_times[name]
    })

    # Print individual results
    print(f"\n{name}:")
    print(f"  Accuracy:  {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall:    {recall:.4f}")
    print(f"  F1-Score:  {f1:.4f}")

# Create results dataframe
results_df = pd.DataFrame(results)
results_df = results_df.round(4)

print("\n" + "=" * 60)
print("SUMMARY TABLE")
print("=" * 60)
display(results_df)
# Out:
# 📊 MODEL EVALUATION
# ============================================================
#
# Logistic Regression:
#   Accuracy:  0.7098
#   Precision: 0.7113
#   Recall:    0.7098
#   F1-Score:  0.7104
#
# Random Forest:
#   Accuracy:  0.7118
#   Precision: 0.7155
#   Recall:    0.7118
#   F1-Score:  0.7031
#
# XGBoost:
#   Accuracy:  0.7569
#   Precision: 0.7575
#   Recall:    0.7569
#   F1-Score:  0.7517
#
# ============================================================
# SUMMARY TABLE
# ============================================================
#                  Model  Accuracy  Precision  Recall  F1-Score  \
# 0  Logistic Regression    0.7098     0.7113  0.7098    0.7104
# 1        Random Forest    0.7118     0.7155  0.7118    0.7031
# 2              XGBoost    0.7569     0.7575  0.7569    0.7517
#
#    Training Time (s)
# 0            17.6443
# 1             4.1716
# 2           170.3656

# %% [markdown]
# Cross-Validation

# %%
print("\n🔄 CROSS-VALIDATION ANALYSIS (5-Fold)")
print("=" * 70)

from sklearn.model_selection import cross_val_score, StratifiedKFold

cv_results = []
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model in trained_models.items():
    print(f"\nCross-validating {name}...")

    # Perform 5-fold cross-validation
    cv_scores = cross_val_score(
        model, X_train, y_train,
        cv=cv_strategy,
        scoring='accuracy',
        n_jobs=1
    )

    cv_results.append({
        'Model': name,
        'CV Mean': cv_scores.mean(),
        'CV Std': cv_scores.std(),
        'CV Min': cv_scores.min(),
        'CV Max': cv_scores.max(),
        'All Folds': cv_scores.tolist()
    })

    print(f"  Mean Accuracy: {cv_scores.mean():.4f} (±{cv_scores.std():.4f})")
    print(f"  Folds: {[f'{s:.4f}' for s in cv_scores]}")

# Create CV DataFrame
cv_df = pd.DataFrame(cv_results)
cv_df_display = cv_df.drop('All Folds', axis=1).round(4)

print("\n" + "=" * 70)
print("CROSS-VALIDATION SUMMARY")
print("=" * 70)
display(cv_df_display)
# Out:
# 🔄 CROSS-VALIDATION ANALYSIS (5-Fold)
# ======================================================================
#
# Cross-validating Logistic Regression...
#   Mean Accuracy: 0.6858 (±0.0201)
#   Folds: ['0.7034', '0.7059', '0.6667', '0.6961', '0.6569']
#
# Cross-validating Random Forest...
#   Mean Accuracy: 0.6873 (±0.0199)
#   Folds: ['0.7059', '0.7010', '0.6912', '0.6495', '0.6887']
#
# Cross-validating XGBoost...
#   Mean Accuracy: 0.7353 (±0.0239)
#   Folds: ['0.7574', '0.7647', '0.7377', '0.7034', '0.7132']
#
# ======================================================================
# CROSS-VALIDATION SUMMARY
# ======================================================================
#                  Model  CV Mean  CV Std  CV Min  CV Max
# 0  Logistic Regression   0.6858  0.0201  0.6569  0.7059
# 1        Random Forest   0.6873  0.0199  0.6495  0.7059
# 2              XGBoost   0.7353  0.0239  0.7034  0.7647

# %% [markdown]
# Confusion Matrices

# %%
print("\n📊 CONFUSION MATRICES - DETAILED ANALYSIS")
print("=" * 70)

# Create 2x2 grid of confusion matrices
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
axes = axes.flatten()

for idx, (name, model) in enumerate(trained_models.items()):
    y_pred = predictions[name]
    cm = confusion_matrix(y_test, y_pred)

    # Plot
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                ax=axes[idx], cbar=True, square=True,
                cbar_kws={'shrink': 0.8})

    # Get accuracy for title
    acc = accuracy_score(y_test, y_pred)

    axes[idx].set_title(f'{name}\nAccuracy: {acc:.4f}',
                       fontsize=14, fontweight='bold', pad=15)
    axes[idx].set_ylabel('True Label', fontsize=12, fontweight='bold')
    axes[idx].set_xlabel('Predicted Label', fontsize=12, fontweight='bold')

plt.suptitle('Confusion Matrices - All Models', fontsize=16, fontweight='bold', y=1.00)
plt.tight_layout()
plt.show()

print("✓ Confusion matrices generated!")
# Out:
# 📊 CONFUSION MATRICES - DETAILED ANALYSIS
# ======================================================================
# ✓ Confusion matrices generated!

# %% [markdown]
# Classification Reports

# %%
print("\n📋 DETAILED CLASSIFICATION REPORTS")
print("=" * 70)

# Get class names if label encoder was used
try:
    if label_encoder is not None:
        target_names = label_encoder.classes_
    else:
        target_names = None
except:
    target_names = None

for name in trained_models.keys():
    y_pred = predictions[name]

    print(f"\n{'='*70}")
    print(f"{name}")
    print(f"{'='*70}")

    if target_names is not None:
        print(classification_report(y_test, y_pred, target_names=target_names, zero_division=0))
    else:
        print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# 📋 DETAILED CLASSIFICATION REPORTS
# ======================================================================
#
# ======================================================================
# Logistic Regression
# ======================================================================
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       245
#            1       0.65      0.67      0.66       202
#            2       0.70      0.67      0.68        63
#
#     accuracy                           0.71       510
#    macro avg       0.70      0.70      0.70       510
# weighted avg       0.71      0.71      0.71       510
#
#
# ======================================================================
# Random Forest
# ======================================================================
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.80       245
#            1       0.64      0.65      0.65       202
#            2       0.80      0.38      0.52        63
#
#     accuracy                           0.71       510
#    macro avg       0.73      0.63      0.65       510
# weighted avg       0.72      0.71      0.70       510
#
#
# ======================================================================
# XGBoost
# ======================================================================
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82       245
#            1       0.73      0.67      0.70       202
#            2       0.81      0.56      0.66        63
#
#     accuracy                           0.76       510
#    macro avg       0.77      0.70      0.73       510
# weighted avg       0.76      0.76      0.75       510

# %% [markdown]
# ROC Curves

# %%
print("\n ROC CURVES")  # display output
print("=" * 60)  # display output

# Determine number of classes
n_classes = len(np.unique(y_train))  # assign variable

if n_classes == 2:  # assign variable
    # Binary classification
    plt.figure(figsize=(16, 12))  # assign variable

    for name in trained_models.keys():  # execute step
        if name in probabilities:  # execute step
            y_prob = probabilities[name][:, 1]  # Probability of positive class  # assign variable
            fpr, tpr, _ = roc_curve(y_test, y_prob)  # assign variable
            roc_auc = auc(fpr, tpr)  # assign variable

            plt.plot(fpr, tpr, linewidth=2,  # assign variable
                    label=f'{name} (AUC = {roc_auc:.3f})')  # assign variable

    plt.plot([0, 1], [0, 1], 'k--', linewidth=2, label='Random Classifier')  # assign variable
    plt.xlim([0.0, 1.0])  # execute step
    plt.ylim([0.0, 1.05])  # execute step
    plt.xlabel('False Positive Rate', fontsize=12)  # assign variable
    plt.ylabel('True Positive Rate', fontsize=12)  # assign variable
    plt.title('ROC Curves - Binary Classification', fontsize=14, fontweight='bold')  # assign variable
    plt.legend(loc='lower right', fontsize=10)  # assign variable
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()
else:

    # Binarize the output
    y_test_bin = label_binarize(y_test, classes=np.unique(y_train))  # assign variable

    fig, axes = plt.subplots(1, 3, figsize=(12, 5))  # assign variable
    axes = axes.flatten()  # assign variable

    for idx, name in enumerate(trained_models.keys()):  # execute step
        if name in probabilities:  # execute step
            y_prob = probabilities[name]  # assign variable

            # Compute ROC curve and AUC for each class
            for i in range(n_classes):  # execute step
                fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_prob[:, i])  # assign variable
                roc_auc = auc(fpr, tpr)  # assign variable
                axes[idx].plot(fpr, tpr, linewidth=2,  # assign variable
                             label=f'Class {i} (AUC = {roc_auc:.3f})')  # assign variable

            axes[idx].plot([0, 1], [0, 1], 'k--', linewidth=2)  # assign variable
            axes[idx].set_xlim([0.0, 1.0])  # execute step
            axes[idx].set_ylim([0.0, 1.05])  # execute step
            axes[idx].set_xlabel('False Positive Rate', fontsize=10)  # assign variable
            axes[idx].set_ylabel('True Positive Rate', fontsize=10)  # assign variable
            axes[idx].set_title(f'{name}', fontsize=12, fontweight='bold')  # assign variable
            axes[idx].legend(loc='lower right', fontsize=8)  # assign variable
            axes[idx].grid(alpha=0.3)  # assign variable

    plt.tight_layout()  # execute step
    plt.show()  # execute step

print(" ROC curves generated!")  # display output
# Out:
#  ROC CURVES
# ============================================================
#  ROC curves generated!

# %% [markdown]
# Model Comparison Visualization

# %%
print("\n📊 MODEL COMPARISON")
print("=" * 60)

# Create comparison plots
fig, axes = plt.subplots(1, 3, figsize=(5, 5))

metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
colors = ['steelblue', 'coral', 'lightgreen', 'gold']

for idx, metric in enumerate(metrics):
    ax = axes[idx // 2, idx % 2]

    values = results_df[metric].values
    models_list = results_df['Model'].values

    bars = ax.barh(models_list, values, color=colors[idx], edgecolor='black', linewidth=1.5)

    # Add value labels on bars
    for i, (bar, val) in enumerate(zip(bars, values)):
        ax.text(val + 0.01, i, f'{val:.4f}',
               va='center', fontsize=10, fontweight='bold')

    ax.set_xlabel(metric, fontsize=12, fontweight='bold')
    ax.set_title(f'{metric} Comparison', fontsize=14, fontweight='bold')
    ax.set_xlim([0, 1.0])
    ax.grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.show()

print("✓ Comparison charts generated!")
# Out:
# 📊 MODEL COMPARISON
# ============================================================
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_412/727150216.py in <cell line: 0>()
#       9
#      10 for idx, metric in enumerate(metrics):
# ---> 11     ax = axes[idx // 1, idx % 1]
#      12
#      13     values = results_df[metric].values
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %% [markdown]
# Feature Importance (Random Forest & XGBoost)

# %%
print("\n🎯 FEATURE IMPORTANCE ANALYSIS")
print("=" * 60)

# Models with feature importance
importance_models = ['Random Forest', 'XGBoost']

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

for idx, name in enumerate(importance_models):
    model = trained_models[name]

    # Get feature importance
    importance = model.feature_importances_

    # Create dataframe
    importance_df = pd.DataFrame({
        'Feature': X_train.columns,
        'Importance': importance
    }).sort_values('Importance', ascending=False)

    # Plot top 20 features
    top_features = importance_df.head(20)

    axes[idx].barh(range(len(top_features)), top_features['Importance'].values,
                  color='steelblue', edgecolor='black')
    axes[idx].set_yticks(range(len(top_features)))
    axes[idx].set_yticklabels(top_features['Feature'].values, fontsize=8)
    axes[idx].invert_yaxis()
    axes[idx].set_xlabel('Importance Score', fontsize=11, fontweight='bold')
    axes[idx].set_title(f'{name}\nTop 20 Features', fontsize=13, fontweight='bold')
    axes[idx].grid(axis='x', alpha=0.3)

    # Print top 10
    print(f"\n{name} - Top 10 Features:")
    for i, row in importance_df.head(10).iterrows():
        print(f"  {row['Feature']}: {row['Importance']:.6f}")

plt.tight_layout()
plt.show()

print("\n✓ Feature importance analysis complete!")

# %% [markdown]
# Best Model Selection

# %%
print("\n🏆 BEST MODEL SELECTION")
print("=" * 60)

# Find best model by accuracy
best_idx = results_df['Accuracy'].idxmax()
best_model_name = results_df.loc[best_idx, 'Model']
best_accuracy = results_df.loc[best_idx, 'Accuracy']

print(f"\n🥇 Best Model: {best_model_name}")
print(f"   Accuracy: {best_accuracy:.4f}")
print(f"   Precision: {results_df.loc[best_idx, 'Precision']:.4f}")
print(f"   Recall: {results_df.loc[best_idx, 'Recall']:.4f}")
print(f"   F1-Score: {results_df.loc[best_idx, 'F1-Score']:.4f}")

# Rank all models
print("\n📊 Model Ranking (by Accuracy):")
ranked = results_df.sort_values('Accuracy', ascending=False)
for i, (idx, row) in enumerate(ranked.iterrows(), 1):
    medal = '🥇' if i == 1 else '🥈' if i == 2 else '🥉' if i == 3 else '  '
    print(f"{medal} {i}. {row['Model']}: {row['Accuracy']:.4f}")
